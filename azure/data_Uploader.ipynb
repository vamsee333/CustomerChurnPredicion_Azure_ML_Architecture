# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential
from azure.ai.ml.entities import Environment, CommandJob, Model, Data
from azure.ai.ml.constants import AssetTypes

# %%
ml_client= MLClient.from_config(credential=DefaultAzureCredential())

data = Data(
    name="customer_churn_data",
    path="../data/overall_data.csv",
    type=AssetTypes.URI_FILE
)

ml_client.data.create_or_update(data)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Uploading overall_data.csv (< 1 MB): 100%|##########| 1.90M/1.90M [00:01<00:00, 1.48MB/s]
# Data({'path': 'azureml://subscriptions/170ad1bf-3f50-46e9-b79d-f22f5e3145b0/resourcegroups/RG1/workspaces/Project_Cloud/datastores/workspaceblobstore/paths/LocalUpload/244186b0e6ca5848724448409572fa1f500f9be805905545786922abc988a218/overall_data.csv', 'skip_validation': False, 'mltable_schema_url': None, 'referenced_uris': None, 'type': 'uri_file', 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'customer_churn_data', 'description': None, 'tags': {}, 'properties': {}, 'print_as_yaml': False, 'id': '/subscriptions/170ad1bf-3f50-46e9-b79d-f22f5e3145b0/resourceGroups/RG1/providers/Microsoft.MachineLearningServices/workspaces/Project_Cloud/data/customer_churn_data/versions/1', 'Resource__source_path': '', 'base_path': 'c:\\Users\\User\\OneDrive\\Desktop\\Customer Churn Prediction Automation\\azure', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x000002830F21C2F0>, 'serialize': <msrest.serialization.Serializer object at 0x00000283113784B0>, 'version': '1', 'latest_version': None, 'datastore': None})
